# %% [markdown]
# # Hellow World
# ### Hello World

# %%
a=1
b=a+2
print(b)
# Out:
# 3

# %%
import numpy as np

a=np.mat('1 2; 3 4')
b=np.mat('1 0; 0 1')
print(a)
print(b)
print(a*b)
# Out:
# [[1 2]
#  [3 4]]
# [[1 0]
#  [0 1]]
# [[1 2]
#  [3 4]]

# %%
c=np.array([[1, 2], [3, 4]])
d=np.array([[1, 0], [0, 1]])
print(c)
print(d)
print(c*d)
# Out:
# [[1 2]
#  [3 4]]
# [[1 0]
#  [0 1]]
# [[1 0]
#  [0 4]]

# %%
print(np.dot(c,d))  # similar to matrix multiplication
# Out:
# [[1 2]
#  [3 4]]

# %%
print(a**2)
# Out:
# [[ 7 10]
#  [15 22]]

# %%
print(c**2)
# Out:
# [[ 1  4]
#  [ 9 16]]
